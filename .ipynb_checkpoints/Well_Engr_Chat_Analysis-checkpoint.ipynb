# %% [markdown]
# ## Analysis of WELL ENGR Group Chat (30/06/2020, 09:21 to 30/06/2021, 17:04)

# %%
pip install plotly_express

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import emoji
from collections import Counter
import plotly.express as px

# %% [markdown]
# Define a function to convert WhatsApp text file into a pandas dataframe

# %%
def parse_file(text_file):
    '''Convert WhatsApp chat log text file to a Pandas dataframe.'''
    
    # some regex to account for messages taking up multiple lines
    pat = re.compile(r'^(\d\d\/\d\d\/\d\d\d\d.*?)(?=^^\d\d\/\d\d\/\d\d\d\d|\Z)', re.S | re.M)
    with open(text_file, encoding = 'utf8') as f:
        data = [m.group(1).strip().replace('\n', ' ') for m in pat.finditer(f.read())]

    sender = []; message = []; datetime = []
    for row in data:

        # timestamp is before the first dash
        datetime.append(row.split(' - ')[0])

        # sender is between dash and colon
        try:
            s = re.search(' - (.*?):', row).group(1)
            sender.append(s)
        except:
            sender.append('')

        # message content is after the first colon
        try:
            message.append(row.split(': ', 1)[1])
        except:
            message.append('')

    df = pd.DataFrame(zip(datetime, sender, message), columns=['timestamp', 'sender', 'message'])
    df['timestamp'] = pd.to_datetime(df.timestamp, format='%d/%m/%Y, %H:%M')

    # remove events not associated with a sender
    df = df[df.sender != ''].reset_index(drop=True)
    
    return df

# %%
#Convert into a dataframe using function defined above and save as df

df = parse_file('14.txt')

# %%
#Check for total number of messages sent by the group

print(f"Total messages: {df.shape[0]}")
# Out:
# Total messages: 7807

# %%
#See sample of dataframe

df.head(50)
# Out:
#              timestamp         sender  \
# 0  2020-06-30 09:21:00     tobi@SHELL
# 1  2020-06-30 09:22:00     tobi@SHELL
# 2  2020-06-30 09:22:00     tobi@SHELL
# 3  2020-06-30 09:22:00     tobi@SHELL
# 4  2020-06-30 09:25:00           Lulu
# 5  2020-06-30 15:09:00           Lulu
# 6  2020-06-30 15:10:00           Lulu
# 7  2020-06-30 15:15:00    Shell@chuka
# 8  2020-06-30 15:18:00           Kosi
# 9  2020-06-30 15:19:00   Shell.judith
# 10 2020-06-30 15:21:00     tobi@SHELL
# 11 2020-06-30 15:21:00     tobi@SHELL
# 12 2020-06-30 15:24:00           Lulu
# 13 2020-06-30 15:24:00           Lulu
# 14 2020-06-30 18:05:00       melchi 🤔
# 15 2020-06-30 18:06:00       melchi 🤔
# 16 2020-06-30 18:06:00           Lulu
# 17 2020-06-30 18:08:00       melchi 🤔
# 18 2020-06-30 18:23:00       melchi 🤔
# 19 2020-06-30 18:24:00       melchi 🤔
# 20 2020-06-30 18:25:00       melchi 🤔
# 21 2020-06-30 18:26:00       melchi 🤔
# 22 2020-06-30 19:24:00         Alfred
# ...

# %%
#Insert an additional column to capture the word count for each row of message

df['totalwords'] = df['message'].str.split().str.len()

# %%
df.tail(5)
# Out:
#                timestamp       sender                     message  totalwords
# 7802 2021-06-30 16:30:00  SHELL@yusuf    Congrats Chuka! good win           4
# 7803 2021-06-30 16:30:00  SHELL@yusuf  Ogbeni u still owe me ooo.           6
# 7804 2021-06-30 16:57:00       Alfred            Well done major.           3
# 7805 2021-06-30 16:57:00       Alfred                       👍🏼👍🏼🎊           1
# 7806 2021-06-30 17:04:00   tobi@SHELL   Congratulations Major....           2

# %%
df['totalwords'].sum()
# Out:
# 72922

# %% [markdown]
# #### Number of Participants in Chat Group and Names

# %%
engineers = df.sender.unique()

# %%
print('Total number of Engineers in Chat Group:', len(engineers),'\n')

increment = 1
for e in engineers:
    print(str(increment) + ': ' + e)
    increment+=1
# Out:
# Total number of Engineers in Chat Group: 15
#
# 1: tobi@SHELL
# 2: Lulu
# 3: Shell@chuka
# 4: Kosi
# 5: Shell.judith
# 6: melchi 🤔
# 7: Alfred
# 8: Chinwe@SHELL
# 9: Lola@shell
# 10: mayowa1@SHELL
# 11: SHELL@majek
# 12: SHELL@yusuf
# 13: bennie@SHELL
# 14: toba@SHELL
# 15: buari@SHELL

# %% [markdown]
# #### Most active users in the group

# %%
sender_df = df.groupby('sender')['message'].count().sort_values(ascending=False).reset_index()
sender_df
# Out:
#            sender  message
# 0        melchi 🤔     1707
# 1            Lulu     1484
# 2     Shell@chuka      722
# 3      toba@SHELL      665
# 4    bennie@SHELL      582
# 5          Alfred      572
# 6      tobi@SHELL      536
# 7    Shell.judith      491
# 8      Lola@shell      340
# 9     SHELL@yusuf      283
# 10    SHELL@majek      133
# 11   Chinwe@SHELL      131
# 12           Kosi       76
# 13    buari@SHELL       47
# 14  mayowa1@SHELL       38

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 13
matplotlib.rcParams['figure.figsize'] = (15, 10)

plt.title("Most active users in group")
barplot = sns.barplot(data=sender_df, x="sender", y="message", palette="CMRmap", dodge=False)
barplot.set_xticklabels(rotation=90, labels=sender_df.sender)
plt.ylabel("no. of messages")
plt.show()
# Out:
# C:\Users\akoga\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 129300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\akoga\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 129300 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### Timeline Range of Captured Chats

# %%
start = df.timestamp.min()
end = df.timestamp.max()

difference = end-start
print("The chat data is captured from {} to {} \n".format(start, end))
print("This covers a range of {} days.".format(difference.days))
# Out:
# The chat data is captured from 2020-06-30 09:21:00 to 2021-06-30 17:04:00
#
# This covers a range of 365 days.

# %% [markdown]
# #### Average Number of Messages Per Day

# %%
average = df.shape[0]/difference.days

# %%
print("Well Engineers sent an average of {} messages per day across the period".format(int(average)))
# Out:
# Well Engineers sent an average of 21 messages per day across the period

# %% [markdown]
# #### Most Active Time of Day in Group Chat

# %%
df["hours"] = df['timestamp'].apply(lambda x: x.hour)
times_df = df.groupby('hours').count().reset_index().sort_values(by = 'hours')

# %%
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['figure.figsize'] = (20, 8)
sns.set_style("darkgrid")

plt.title('Most active hour in Chat Group');
time_plot = sns.barplot(x="hours",y="message", data = times_df,dodge=False)
labels=["12AM","1AM","2AM","3AM","4AM","5AM","6AM","7AM","8AM","9AM","10AM","11AM","12PM","1PM","2PM","3PM","4PM","5PM","6PM","7PM","8PM","9PM","10PM","11PM"]

plt.xticks([i for i in range(24)], labels=labels, rotation=70)
plt.show()

# %% [markdown]
# #### Most Active Months of Conversation

# %%
df["months"] = df['timestamp'].apply(lambda x: x.month)
month_df = df.groupby('months').count().reset_index().sort_values(by = 'months')

# %%
matplotlib.rcParams['font.size'] = 18
matplotlib.rcParams['figure.figsize'] = (20, 8)
sns.set_style("darkgrid")

plt.title('Messages Sent per Month');

month_plot = sns.barplot(x="message", y="months", orient="h", data=month_df)
labels = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
plt.yticks(ticks=[i for i in range(12)], labels=labels, rotation=0)
plt.show()

# %%
matplotlib.rcParams['font.size'] = 18
matplotlib.rcParams['figure.figsize'] = (20, 8)
sns.set_style("darkgrid")

plt.title('Month on Month Change in Activity');

month_plot = sns.lineplot(x="months", y="message", data=month_df)
labels = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
plt.xticks(ticks=[i for i in range(1,13)], labels=labels, rotation=0)
plt.show()

# %% [markdown]
# #### Most used Emoji's

# %%
emoji_counter = Counter()

emoji_list = list(emoji.UNICODE_EMOJI_ENGLISH.keys())
r = re.compile('|'.join(re.escape(p) for p in emoji_list))


for idx, row in df.iterrows():
    found = r.findall(row["message"])
    for emojif in found:
        emoji_counter[emojif] += 1

# %%
emojis_df = pd.DataFrame()

# %%
emojis_df['emoji'] = [''] * 20
emojis_df['number_of_Emoji'] = [0] * 20

# %%
i = 0
for item in emoji_counter.most_common(20):
    emojis_df.emoji[i] = item[0]
    emojis_df.number_of_Emoji[i] = int(item[1])
    i += 1
# Out:
# <ipython-input-24-c2bb6f38ebce>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emojis_df.emoji[i] = item[0]
# <ipython-input-24-c2bb6f38ebce>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emojis_df.number_of_Emoji[i] = int(item[1])

# %%
emojis_df.shape
# Out:
# (20, 2)

# %%
emojis_df
# Out:
#    emoji  number_of_Emoji
# 0      🤣             1472
# 1      😂              675
# 2      😁              349
# 3      😭              206
# 4      👍              140
# 5      😳               96
# 6      🙈               90
# 7      🤨               74
# 8      🏿               67
# 9      🙄               67
# 10     😝               64
# 11     🏽               63
# 12     😒               53
# 13     👀               50
# 14     🤔               46
# 15     🎉               44
# 16     ♀               44
# 17     🍾               43
# 18     🏼               43
# 19     😡               41

# %%
fig = px.pie(emojis_df, values='number_of_Emoji', names='emoji',title='Emoji Usage by Percentage', width=800, height=800)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="8b4841de-71f8-45ba-b5d1-173f695dbec4" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b4841de-71f8-45ba-b5d1-173f695dbec4")) {                    Plotly.newPlot(                        "8b4841de-71f8-45ba-b5d1-173f695dbec4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"emoji=%{label}<br>number_of_Emoji=%{value}<extra></extra>","labels":["\ud83e\udd23","\ud83d\ude02","\ud83d\ude01","\ud83d\ude2d","\ud83d\udc4d","\ud83d\ude33","\ud83d\ude48","\ud83e\udd28","\ud83c\udfff","\ud83d\ude44","\ud83d\ude1d","\ud83c\udffd","\ud83d\ude12","\ud83d\udc40","\ud83e\udd14","\ud83c\udf89","\u2640","\ud83c\udf7e","\ud83c\udffc","\ud83d\ude21"],"legendgroup":"","name":"","showlegend":true,
# ...

# %% [markdown]
# #### Emoji Usage by Engineers

# %%
user_emoji_df = df.copy()

# %%
user_emoji_df
# Out:
#                timestamp       sender  \
# 0    2020-06-30 09:21:00   tobi@SHELL
# 1    2020-06-30 09:22:00   tobi@SHELL
# 2    2020-06-30 09:22:00   tobi@SHELL
# 3    2020-06-30 09:22:00   tobi@SHELL
# 4    2020-06-30 09:25:00         Lulu
# ...                  ...          ...
# 7802 2021-06-30 16:30:00  SHELL@yusuf
# 7803 2021-06-30 16:30:00  SHELL@yusuf
# 7804 2021-06-30 16:57:00       Alfred
# 7805 2021-06-30 16:57:00       Alfred
# 7806 2021-06-30 17:04:00   tobi@SHELL
#
#                                                 message  totalwords  hours  \
# 0                           Abeg make una go vote ooooo           6      9
# 1                               We need early lead oooo           5      9
# 2                         https://evote.cooplag.com.ng/           1      9
# 3     Lulu you can vote on ur phone without logging ...          12      9
# 4                              Ok I’d vote via my phone           6      9
# ...

# %%
def emojis_list(x):
    emo_list = []
    found = r.findall(x)
    for emoji_found in found:
        emo_list.append(emoji_found)
    return emo_list

# %%
user_emoji_df["list of emojis"] = user_emoji_df["message"].apply(lambda x : emojis_list(x))

# %%
user_emoji_df
# Out:
#                timestamp       sender  \
# 0    2020-06-30 09:21:00   tobi@SHELL
# 1    2020-06-30 09:22:00   tobi@SHELL
# 2    2020-06-30 09:22:00   tobi@SHELL
# 3    2020-06-30 09:22:00   tobi@SHELL
# 4    2020-06-30 09:25:00         Lulu
# ...                  ...          ...
# 7802 2021-06-30 16:30:00  SHELL@yusuf
# 7803 2021-06-30 16:30:00  SHELL@yusuf
# 7804 2021-06-30 16:57:00       Alfred
# 7805 2021-06-30 16:57:00       Alfred
# 7806 2021-06-30 17:04:00   tobi@SHELL
#
#                                                 message  totalwords  hours  \
# 0                           Abeg make una go vote ooooo           6      9
# 1                               We need early lead oooo           5      9
# 2                         https://evote.cooplag.com.ng/           1      9
# 3     Lulu you can vote on ur phone without logging ...          12      9
# 4                              Ok I’d vote via my phone           6      9
# ...

# %%
def sender_emoji(sender):
    # filter the user_emoji_df to return only the rows that match a particular sender
    sender = user_emoji_df[user_emoji_df["sender"] == sender]
    
    # create an empty list which would be used to collate all emoji's sent by this sender
    sender_list = []
    
    # iterate through the filtered dataframe to collect all emoji's into the sender_list
    for item in sender["list of emojis"]:
        if len(item) != 0:
            sender_list += item
            
    # create an empty dictionary to be used in aggregating the emoji count       
    sender_dict = {}
    
    for emoji in sender_list:
        if emoji in sender_dict:
            sender_dict[emoji] += 1
        else:
            sender_dict[emoji] = 1
    
    # convert dictionary into pandas dataframe
    sender_emoji_df = pd.DataFrame(sender_dict, index=['Count']).T.sort_values(by='Count', ascending=False)
    
    return sender_emoji_df

# %%
jud = sender_emoji("Shell.judith")
jud
# Out:
#       Count
# 😁        93
# ☺        22
# 👍        21
# 👏        12
# 🤣        11
# 🤦‍♂️      7
# 🤪         5
# 🤔         5
# 🙏         3
# ☝         2
# 😂         2
# 😧         2
# 🍻         1
# 🥰         1
# 🤛         1
# 🏾         1

# %%
jud.shape
# Out:
# (16, 1)

# %%
fig = px.pie(jud, values='Count', names=jud.index, title='Judith Emoji Usage', width=500, height=500)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <div>                            <div id="58212e12-1ce7-414e-8e78-31cdd3249ddb" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58212e12-1ce7-414e-8e78-31cdd3249ddb")) {                    Plotly.newPlot(                        "58212e12-1ce7-414e-8e78-31cdd3249ddb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>Count=%{value}<extra></extra>","labels":["\ud83d\ude01","\u263a","\ud83d\udc4d","\ud83d\udc4f","\ud83e\udd23","\ud83e\udd26\u200d\u2642\ufe0f","\ud83e\udd2a","\ud83e\udd14","\ud83d\ude4f","\u261d","\ud83d\ude02","\ud83d\ude27","\ud83c\udf7b","\ud83e\udd70","\ud83e\udd1b","\ud83c\udffe"],"legendgroup":"","name":"","showlegend":true,"textinfo":"percent+label","textposition":"inside","type":
# ...

# %%
fig = px.bar(jud, x=jud.index, y='Count', title='Judith Emoji Usage')
fig.show()
# Out:
# <div>                            <div id="801ee4ad-a94b-48b9-a719-f16da06175c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("801ee4ad-a94b-48b9-a719-f16da06175c7")) {                    Plotly.newPlot(                        "801ee4ad-a94b-48b9-a719-f16da06175c7",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["\ud83d\ude01","\u263a","\ud83d\udc4d","\ud83d\udc4f","\ud83e\udd23","\ud83e\udd26\u200d\u2642\ufe0f","\ud83e\udd2a","\ud83e\udd14","\ud83d\ude4f","\u261d","\ud83d\ude02","\ud83d\ude27","\ud83c\udf7b","\ud83e\ud
# ...

# %% [markdown]
# #### Commonly Used Words

# %%
stopwords = set(STOPWORDS)

word = " ".join(word for word in df.message)
#stopwords.update(["the","is","yea","ok","okay","or","bye","no","will","yeah","I","almost","if","me","you","done","want","Ya"])

wordcloud = WordCloud(width = 800, height =800 ,stopwords=stopwords, background_color="black",min_font_size = 10).generate(word)

plt.figure( figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x1D9CE9EA730>

# %% [markdown]
# "Media omitted" refers to the sending of multimedia messages.

# %% [markdown]
# #### Alternate Method for Group Emoji Usage

# %%
def group_emoji():
    
    # create an empty list which would be used to collate all emoji's sent by the group
    sender_list = []
    
    # iterate through the filtered dataframe to collect all emoji's into the sender_list
    for item in user_emoji_df["list of emojis"]:
        if len(item) != 0:
            sender_list += item
            
    # create an empty dictionary to be used in aggregating the emoji count       
    sender_dict = {}
    
    for emoji in sender_list:
        if emoji in sender_dict:
            sender_dict[emoji] += 1
        else:
            sender_dict[emoji] = 1
    
    # convert dictionary into pandas dataframe
    sender_emoji_df = pd.DataFrame(sender_dict, index=['Count']).T.sort_values(by='Count', ascending=False)
    
    return sender_emoji_df

# %%
group_emoji()[0:10]
# Out:
#    Count
# 🤣   1472
# 😂    675
# 😁    349
# 😭    206
# 👍    140
# 😳     96
# 🙈     90
# 🤨     74
# 🙄     67
# 🏿     67

# %% [markdown]
# #### Who Sends the Longest Messages on Average

# %%
message_df = df.copy()

# %%
message_df['characters'] = message_df.message.apply(len)
message_df['words'] = message_df.message.apply(lambda x: len(x.split()))

word_df = message_df.groupby('sender').mean().sort_values('words', ascending=False).round(2)

# %%
word_df.drop(['totalwords', 'hours', 'months'], axis=1, inplace=True)

# %%
word_df
# Out:
#                characters  words
# sender
# SHELL@yusuf        122.80  22.37
# SHELL@majek         75.91  14.23
# toba@SHELL          75.36  12.46
# Alfred              61.06  11.26
# mayowa1@SHELL       55.74  10.16
# buari@SHELL         56.79  10.15
# melchi 🤔            52.48   9.14
# bennie@SHELL        47.46   8.75
# Lola@shell          44.73   8.18
# Lulu                42.42   8.08
# Shell.judith        44.43   7.84
# Shell@chuka         37.75   6.87
# tobi@SHELL          37.35   6.82
# Kosi                32.03   5.95
# Chinwe@SHELL        31.83   5.59

# %%
word_df.mean()
# Out:
# characters    54.542667
# words          9.856667
# dtype: float64

# %% [markdown]
# #### Distinct conversations within the group
#
# Let's define a conversation as a stream of messages where the gap between any two messages is not longer than 20 minutes.

# %%
converse_df = df.copy()

# %%
converse_df.head(3)
# Out:
#             timestamp      sender                        message  totalwords  \
# 0 2020-06-30 09:21:00  tobi@SHELL    Abeg make una go vote ooooo           6
# 1 2020-06-30 09:22:00  tobi@SHELL        We need early lead oooo           5
# 2 2020-06-30 09:22:00  tobi@SHELL  https://evote.cooplag.com.ng/           1
#
#    hours  months
# 0      9       6
# 1      9       6
# 2      9       6

# %%
# find time difference between current and previous message
converse_df['reply_time'] = (converse_df.timestamp.shift(-1) - converse_df.timestamp).apply(lambda x: x.total_seconds()/60).fillna(np.inf)

# %%
# if reply time is more than 20 mins add 1 to counter
converse_df['conversation'] = (converse_df.reply_time > 20).cumsum().shift(1).fillna(0).astype(int) + 1

# %%
df1 = converse_df.groupby('conversation').agg({'timestamp': ['min', 'max', 'count'], 
                                      'sender': ['first', 'unique', 'nunique']})

# %%
df1['duration'] = (df1['timestamp']['max'] - df1['timestamp']['min']).apply(lambda x: x.total_seconds()/60)

# %%
converse_df
# Out:
#                timestamp       sender  \
# 0    2020-06-30 09:21:00   tobi@SHELL
# 1    2020-06-30 09:22:00   tobi@SHELL
# 2    2020-06-30 09:22:00   tobi@SHELL
# 3    2020-06-30 09:22:00   tobi@SHELL
# 4    2020-06-30 09:25:00         Lulu
# ...                  ...          ...
# 7802 2021-06-30 16:30:00  SHELL@yusuf
# 7803 2021-06-30 16:30:00  SHELL@yusuf
# 7804 2021-06-30 16:57:00       Alfred
# 7805 2021-06-30 16:57:00       Alfred
# 7806 2021-06-30 17:04:00   tobi@SHELL
#
#                                                 message  totalwords  hours  \
# 0                           Abeg make una go vote ooooo           6      9
# 1                               We need early lead oooo           5      9
# 2                         https://evote.cooplag.com.ng/           1      9
# 3     Lulu you can vote on ur phone without logging ...          12      9
# 4                              Ok I’d vote via my phone           6      9
# ...

# %%
df1
# Out:
#                        timestamp                                 sender  \
#                              min                 max count        first
# conversation
# 1            2020-06-30 09:21:00 2020-06-30 09:25:00     5   tobi@SHELL
# 2            2020-06-30 15:09:00 2020-06-30 15:24:00     9         Lulu
# 3            2020-06-30 18:05:00 2020-06-30 18:26:00     8     melchi 🤔
# 4            2020-06-30 19:24:00 2020-06-30 19:24:00     1       Alfred
# 5            2020-07-01 07:37:00 2020-07-01 07:50:00     3     melchi 🤔
# ...                          ...                 ...   ...          ...
# 1192         2021-06-30 08:46:00 2021-06-30 09:50:00    52   tobi@SHELL
# 1193         2021-06-30 11:11:00 2021-06-30 11:13:00     2  SHELL@yusuf
# 1194         2021-06-30 11:45:00 2021-06-30 11:53:00    14       Alfred
# 1195         2021-06-30 16:04:00 2021-06-30 16:30:00     7   toba@SHELL
# 1196         2021-06-30 16:57:00 2021-06-30 17:04:00     3       Alfred
#
# ...

# %%
df1.mean()
# Out:
# <ipython-input-130-00fb6bfec183>:1: FutureWarning:
#
# DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
# timestamp  count       6.527592
# sender     nunique     2.229933
# duration              10.945652
# dtype: float64

# %% [markdown]
# ##### By this method we identify 1,196 conversations. The average conversation lasts 10.9 minutes, is made up of 6.5 messages from 2 participants.

# %% [markdown]
# ####  Who starts the most conversations?

# %%
starts_df1= df1['sender']['first'].value_counts()

# %%
starts_df1
# Out:
# melchi 🤔         299
# Lulu             149
# Alfred           143
# toba@SHELL       114
# Shell@chuka      106
# SHELL@yusuf       84
# Shell.judith      66
# tobi@SHELL        61
# Lola@shell        50
# bennie@SHELL      38
# Chinwe@SHELL      34
# mayowa1@SHELL     19
# Kosi              14
# buari@SHELL       12
# SHELL@majek        7
# Name: first, dtype: int64

# %%
starts_df= starts_df1.to_frame()

# %%
starts_df.reset_index(level=0, inplace=True)

# %%
starts_df.rename(columns={"index": "sender"}, inplace=True)

# %%
starts_df
# Out:
#            sender  first
# 0        melchi 🤔    299
# 1            Lulu    149
# 2          Alfred    143
# 3      toba@SHELL    114
# 4     Shell@chuka    106
# 5     SHELL@yusuf     84
# 6    Shell.judith     66
# 7      tobi@SHELL     61
# 8      Lola@shell     50
# 9    bennie@SHELL     38
# 10   Chinwe@SHELL     34
# 11  mayowa1@SHELL     19
# 12           Kosi     14
# 13    buari@SHELL     12
# 14    SHELL@majek      7

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['figure.figsize'] = (15, 7)

plt.title("Who Starts the Most Conversations")
barplot = sns.barplot(data=starts_df, x="sender", y="first", palette="CMRmap", dodge=False)
barplot.set_xticklabels(rotation=90, labels=starts_df.sender)
plt.ylabel("no. of conversations started")
plt.show()
# Out:
# C:\Users\akoga\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 129300 missing from current font.
#
# C:\Users\akoga\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning:
#
# Glyph 129300 missing from current font.

# %% [markdown]
# #### Weekend vs Weekday Usage Pattern?

# %%
day_df = df.copy()

# %%
day_df['weekday'] = day_df['timestamp'].apply(lambda x: x.day_name())

# %%
day_df['is_weekend'] = day_df.weekday.isin(['Sunday', 'Saturday'])

# %%
day_df.sample(5)
# Out:
#                timestamp       sender  \
# 5675 2021-03-25 17:38:00  Shell@chuka
# 7323 2021-05-29 20:56:00         Lulu
# 5287 2021-02-27 09:28:00     melchi 🤔
# 82   2020-07-01 13:04:00         Lulu
# 6632 2021-04-29 12:20:00         Lulu
#
#                                                 message  totalwords  hours  \
# 5675  Can we all agree to calling Joe Joe and not Og...          12     17
# 7323                   Hmmm Bart, I can already imagine           6     20
# 5287                   This stuff is going to get worse           7      9
# 82    Let Thierry tell them to go and drill the well...          11     13
# 6632                                   🤣🤣🙈 under bed na           4     12
#
#       months    weekday  is_weekend
# 5675       3   Thursday       False
# 7323       5   Saturday        True
# 5287       2   Saturday        True
# 82         7  Wednesday       False
# 6632       4   Thursday       False

# %%
plt.figure(figsize=(30,15))
sns.countplot(x="sender", hue="weekday", data=day_df).set_xticklabels(rotation=90, labels=['tobi', 'lulu', 'major', 'kosi', 'judith', 'melchi', 'alfred', 'chinwe', 'molly', 'owoni', 'majek', 'alhaji', 'bennie', 'toba', 'buari'])
plt.show()

# %%
plt.figure(figsize=(30,15))
sns.countplot(x="sender", hue="is_weekend", data=day_df)
plt.show()
# Out:
# C:\Users\akoga\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning:
#
# Glyph 129300 missing from current font.
#
# C:\Users\akoga\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning:
#
# Glyph 129300 missing from current font.

# %%
total_words_weekday = day_df[day_df['is_weekend']==False]['totalwords'].sum()
total_words_weekday
# Out:
# 62920

# %%
total_words_weekend = day_df[day_df['is_weekend']]['totalwords'].sum()
total_words_weekend
# Out:
# 10002

# %%
# average words on a weekday

print(f"The average number of Words per day on Weekday is: {total_words_weekday/5}")
# Out:
# The average number of Words per day on Weekday is: 12584.0

# %%
# average words on a weekend

print(f"The average number of Words per day on Weekend is: {total_words_weekend/2}")
# Out:
# The average number of Words per day on Weekend is: 5001.0

# %%
x = day_df.groupby(['hours', 'weekday'])['message'].size().reset_index()


#daydf = day_df.pivot("weekday", "sender", "totalwords")
#ax = sns.heatmap(daydf)

# %%
x2 = x.pivot("hours", 'weekday', 'message')
x2.tail(5)
# Out:
# weekday  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# hours
# 19         68.0    32.0      17.0     6.0      83.0     61.0       58.0
# 20         48.0    44.0      14.0     1.0     103.0     42.0       34.0
# 21         50.0    23.0       9.0     6.0      15.0     13.0       73.0
# 22         34.0    28.0      13.0    17.0       1.0    108.0       53.0
# 23         16.0    30.0       4.0     2.0       7.0     45.0        9.0

# %%
days = ["Monday", 'Tuesday', "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
sns.heatmap(x2[days].fillna(0), cmap="YlGnBu", linewidths=.5, robust=True)
# Out:
# <AxesSubplot:xlabel='weekday', ylabel='hours'>
